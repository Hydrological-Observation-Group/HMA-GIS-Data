# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
path_hma_extent = "data/hma-extent/HMA/hma_gtng_202307_subregions.gpkg"
path_lake_sam = "data/validation/water-glacier-samples/lake_sample_2020.gpkg"

# %%
hma = gpd.read_file(path_hma_extent)
lake_sample = gpd.read_file(path_lake_sam)

# %%
lake_sample.head(5)
# Out:
#   Sample_id  id      type characteristic  longtitude   latitude  \
# 0      TP_1   1  non-lake         shadow   90.566099  27.861351
# 1      TP_2   2  non-lake         shadow   90.448950  29.355756
# 2      TP_3   3  non-lake          river   90.426356  28.941104
# 3      TP_4   4  non-lake        glacier   90.203285  29.039378
# 4      TP_5   5      lake           edge   90.459192  30.875279
#
#              Date                             S2_Image_ID  \
# 0  2020/8/27 4:50  20200928T042709_20200928T043035_T46RBR
# 1  2020/8/17 4:49  20200827T043711_20200827T044502_T46RBT
# 2  2020/9/29 4:59  20200827T043711_20200827T044502_T46RBT
# 3  2020/9/29 4:59  20200827T043711_20200827T044502_T46RBT
# 4  2020/6/23 4:48  20200827T043711_20200827T044502_T46RBV
#
#                     geometry
# 0   POINT (90.5661 27.86135)
# 1  POINT (90.44895 29.35576)
# 2   POINT (90.42636 28.9411)
# 3  POINT (90.20328 29.03938)
# 4  POINT (90.45919 30.87528)

# %%
# 可视化展示
fig, ax = plt.subplots(figsize=(10, 8))

hma.boundary.plot(
    ax=ax, 
    edgecolor="black", 
    linewidth=0.6, 
    label="HMA boundary"
)

lake_sample.plot(
    ax=ax, 
    color="blue",       
    marker="o",       
    markersize=6,     
    label="Lake validation points",
    alpha=0.4          
)

ax.legend()
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.grid(True, linestyle="--", alpha=0.4)
ax.set_title("Lake Validation Points in HMA")

plt.show()

# %%
# 4. 保存和展示
fig.savefig("figures/validation/lake_sample.png", bbox_inches='tight', dpi=200)
